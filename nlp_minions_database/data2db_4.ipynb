# %%
import glob

post_path = "C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\*"
Relation_path = "C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\*"
post_file_list = glob.glob(post_path)
relation_file_list = glob.glob(Relation_path)

# %%
post_file_list
# Out:
# ['C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\gs_post.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\gw_post.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\jl_post.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\sd_post.csv']

# %%
relation_file_list
# Out:
# ['C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\cc_1.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\cc_2.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\gs_1.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\gs_2.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\gw_1.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\gw_2.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\jl_1.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\jl_2.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\sd_1.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Relation\\sd_2.csv']

# %%
import pandas as pd

gs_post_data = pd.read_csv(post_file_list[0])
gs_post_data
# Out:
#           shortcode   insta_id     inner_id            post_date  \
# 0       CB-kragHtB1  mint_seul      3233588  2020-06-28 20:50:17
# 1       CBRjjjLHBeH  mint_seul      3233588  2020-06-11 09:14:38
# 2       CBRjPgnHo56  mint_seul      3233588  2020-06-11 09:11:54
# 3       CBMk6R0lqQ4  mint_seul      3233588  2020-06-09 10:51:02
# 4       CBIKM-HnnWc  mint_seul      3233588  2020-06-07 17:41:13
# ...             ...        ...          ...                  ...
# 131568  CD_eeLhlqs3   mubwatna  40326344549  2020-08-17 22:18:04
# 131569  CD8Sr4dlRiu   mubwatna  40326344549  2020-08-16 16:37:22
# 131570  CDxzTHih8zy   mubwatna  40326344549  2020-08-12 14:50:42
# 131571  CDxv59lBVWt   mubwatna  40326344549  2020-08-12 14:21:03
# 131572  CDxsWelhnXO   mubwatna  40326344549  2020-08-12 13:49:59
#
#                                              url  \
# 0       https://www.instagram.com/p/CB-kragHtB1/
# 1       https://www.instagram.com/p/CBRjjjLHBeH/
# ...

# %%
gs_post_data['team_idx'] = '4'

# %%
import json

gs_post_data_list = []
for i in range(10):
    
    if(str(gs_post_data['hashtag'][i]) != 'nan'):
        hashtag = str(gs_post_data['hashtag'][i]).replace(' #', ', ')[1:]
    else:
        hashtag = gs_post_data['hashtag'][i]
    
    if(str(gs_post_data['like_count'][i]) != 'nan'):
        like_count = str(gs_post_data['like_count'][i])
    else:
        like_count = gs_post_data['like_count'][i]
        
    if(str(gs_post_data['view_count'][i]) != 'nan'):
        view_count = str(gs_post_data['view_count'][i])
    else:
        view_count = gs_post_data['view_count'][i]
        
    gs_post_data_list.append(
        {"inner_id": str(gs_post_data['inner_id'][i]),
         "post_date": gs_post_data['post_date'][i],
         "crawling_time": gs_post_data['crawling_time'][i],
         "like_count": gs_post_data['like_count'][i],
         "view_count" : gs_post_data['view_count'][i],
         "url" : gs_post_data['url'][i],
         "shortcode" : gs_post_data['shortcode'][i],
         "media_url" : gs_post_data['media_url'][i], 
         "content" : gs_post_data['content'][i],
         "region_tag" : gs_post_data['region_tag'][i],
         "hashtag" : hashtag,
         "team_idx" : gs_post_data['team_idx'][i]
        })

# %%
import requests 

def input_post_data(list_data):
    post_URL = 'http://220.90.200.172:3000/data/post' 
    post_data_dic = {}
    post_data_dic["data"] = list_data
    json_string = json.dumps(post_data_dic).replace('NaN', '')
    print(json_string)
    post_res = requests.post(post_URL, data=json_string)
    print(post_res)
    return post_res

# %%
test = input_post_data(gs_post_data)

# %%
import pandas as pd

cc_relation_data = pd.read_csv(relation_file_list[0])
cc_relation_data
# Out:
#            start          end
# 0    40817735077  13580068590
# 1     4160055907  13580068590
# 2     5802261793  13580068590
# 3    23898132889  13580068590
# 4    40384414061  13580068590
# ..           ...          ...
# 168  13580068590   3917675105
# 169  13580068590   9681937631
# 170  13580068590  12731449978
# 171  13580068590   7437102072
# 172  13580068590  13245118330
#
# [173 rows x 2 columns]
