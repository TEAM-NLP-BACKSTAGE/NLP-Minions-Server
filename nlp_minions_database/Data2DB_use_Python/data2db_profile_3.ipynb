# %%
# Python2DB class
import pymysql


class Python2DB():
    def __init__(self):
        self.WL_DB = pymysql.connect(host='220.90.200.176',
                                     port=3306,
                                     user='multi',
                                     passwd='multi!)@(',
                                     db = 'SocialAnalysis',
                                     charset='utf8')
        self.cursor = self.WL_DB.cursor()
        
    def select(self, table, column):
        sql_qr = """
            SELECT {0} FROM {1}
        """.format(column, table)
        self.cursor.execute(sql_qr)
        return self.cursor.fetchall()

    def insert(self, table, columns, values):
        sql_qr2 = """
            INSERT INTO {0}({1})
            VALUES ({2})
        """.format(table, columns, values)
        self.cursor.execute(sql_qr2)
        self.WL_DB.commit()

    def update(self, table, set_content, where_content):
        sql_qr3 = """
            UPDATE {0}
            SET {1}
            WHERE {2}
        """.format(table, set_content, where_content)
        self.cursor.execute(sql_qr3)
        self.WL_DB.commit()

    def delete(self, table, where_content):
        sql_qr4 = """
            DELETE FROM {0} WHERE {1}
        """.format(table, where_content)
        self.cursor.execute(sql_qr4)
        self.WL_DB.commit()

# %%
# 폴더 내 파일을 모두 불러옴(생략가능)
import glob

file_path = "C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\*"
file_list = glob.glob(file_path)
file_list
# Out:
# ['C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\FOLLOW_RELATION.json',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\INSTA_FOLLOW_POST.txt',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\INSTA_POST_FINAL.txt',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\INSTA_USERS.txt']

# %%
# 파일을 데이터프레임으로 불러옴
import pandas as pd

profile_data = pd.read_csv(file_list[3])
profile_data
# Out:
#        Unnamed: 0   index hashtag            post_date        crawling_time  \
# 0               0       0      운동  2020-08-21 13:38:56  2020-08-21 13:37:22
# 1               1       1      운동  2020-08-21 13:38:36  2020-08-21 13:37:22
# 2               2       2      운동  2020-08-21 13:38:35  2020-08-21 13:37:22
# 3               3       3      운동  2020-08-21 13:38:30  2020-08-21 13:37:22
# 4               4       4      운동  2020-08-21 13:38:12  2020-08-21 13:37:22
# ...           ...     ...     ...                  ...                  ...
# 81971       81971  135574   movie  2020-08-21 19:00:09  2020-08-21 20:21:10
# 81972       81972  135575   movie  2020-08-21 18:59:18  2020-08-21 20:21:10
# 81973       81973  135576   movie  2020-08-21 18:54:08  2020-08-21 20:21:10
# 81974       81974  135577   movie  2020-08-21 15:55:52  2020-08-21 20:21:10
# 81975       81975  135578   movie  2020-08-21 14:07:01  2020-08-21 20:21:10
#
#           insta_id
# 0       1319299351
# 1       1458703146
# 2      36593513387
# 3       2353695326
# 4      10229940161
# ...            ...
# 81971   1690786950
# 81972  38769614076
# 81973   8011539079
# 81974  39992191790
# 81975   8419953219
#
# [81976 rows x 6 columns]

# %%
import re

db_class = Python2DB()  # 클래스 객체 선언
post_data_list = []  # 데이터 확인을 위한 리스트 선언
id_list = list(set(profile_data['insta_id']))  # 중복 제거 후 inner_id 리스트
len_id_list = len(id_list)

for i in range(len_id_list):  # 데이터프레임의 크기만큼 돌게 설정
    
    inner_id = str(id_list[i])
    interest = list(profile_data['hashtag'][profile_data['insta_id'] == id_list[i]])[0]
    
    post_data_list.append(
        {"inner_id": inner_id,
         "interest": interest
        })
    try:
        db_class.update('INSTA_PROFILE', "interest = '" + interest + "'", "inner_id = '" + inner_id + "'")
    except:
        print("error = " +  "interest = '" + interest + "'" + "\ninner_id = '" + inner_id + "'")
        pass

# %%
follow_relation_data = pd.read_json(file_list[0])
follow_relation_data
# Out:
#             insta_id    follow_id           follow_name      follow_fullname
# 0         4922234371  39306761196            miu_____ng                    y
# 1         4922234371   3680315716            angler_seo         앵글러 서태공 , 배배
# 2         4922234371   4514980397     dasolfishing_mart               다솔낚시마트
# 3         4922234371  10014374186       garminsports_kr  가민 스포츠 코리아
# 4         4922234371  14010195784            ju__nhyeok        junhyeok Choi
# ...              ...          ...                   ...                  ...
# 2006706  26970769219   8722179315   zaigle_zwc.official  ZAIGLE ZWC.official
# 2006707  26970769219  12743642616             the_zooen               주 은 ❤️
# 2006708  26970769219   6115485784  mycafelatte_official       나만의 카페, 마이카페라떼
# 2006709  26970769219   1007601508              iris9199                  한천수
# 2006710  26970769219   9124019681                kold72                   콜듀
#
# [2006711 rows x 4 columns]

# %%
import re

db_class = Python2DB()  # 클래스 객체 선언
post_data_list = []  # 데이터 확인을 위한 리스트 선언
id_list = list(set(follow_relation_data['follow_id']))  # 중복 제거 후 inner_id 리스트
len_id_list = len(id_list)

for i in range(len_id_list):  # 데이터프레임의 크기만큼 돌게 설정
    
    inner_id = str(id_list[i])
    insta_id = list(follow_relation_data['follow_name'][follow_relation_data['follow_id'] == id_list[i]])[0]
    
    post_data_list.append(
        {"inner_id": inner_id,
         "insta_id": insta_id
        })
    try:
        db_class.update('INSTA_PROFILE', "insta_id = '" + insta_id + "'", "inner_id = '" + inner_id + "'")
    except:
        print("error = " +  "insta_id = '" + insta_id + "'" + "\ninner_id = '" + inner_id + "'")
        pass

# %%
import re

db_class = Python2DB()  # 클래스 객체 선언
post_data_list = []  # 데이터 확인을 위한 리스트 선언
id_list = list(set(follow_relation_data['follow_id']))  # 중복 제거 후 inner_id 리스트
len_id_list = len(id_list)
EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)  # 이모티콘 제거를 위한 EMOJI 변수

for i in range(len_id_list):  # 데이터프레임의 크기만큼 돌게 설정
    
    inner_id = str(id_list[i])
    profile =  EMOJI.sub(r'', list(follow_relation_data['follow_fullname'][follow_relation_data['follow_id'] == id_list[i]])[0]).replace(',', '  ').replace('"', '').replace("'", "")
    
    post_data_list.append(
        {"inner_id": inner_id,
         "profile": profile
        })
    try:
        db_class.update('INSTA_PROFILE', "profile = '" + profile + "'", "inner_id = '" + inner_id + "'")
    except:
        print("error = " +  "profile = '" + profile + "'" + "\ninner_id = '" + inner_id + "'")
        pass
# Out:
# error = profile = '쏘\(//∇//)\'
# inner_id = '878789308'
# error = profile = '/ㅡ연희(19)_\'
# inner_id = '3072518077'
# error = profile = ' 알라\'
# inner_id = '409234576'
# error = profile = '이윤경\ ᴀᴋᴀ.지원맘 \'
# inner_id = '15225781476'
# error = profile = '강아지 ੯‧̀͡u\'
# inner_id = '8559000670'
# error = profile = '੯‧̀͡u\'
# inner_id = '7013403189'
# error = profile = 'tranquille \tʁɑ̃.kil\'
# inner_id = '2246801597'
# error = profile = '롱보드 원상 /sang won\'
# inner_id = '2714471610'
# error = profile = '코코 밀크 ੯‧̀͡u\'
# inner_id = '34159175180'
# error = profile = 'Wienimals \wē-nə-məls\'
# inner_id = '2253173259'
# error = profile = '੯‧̀͡u\'
# inner_id = '40048048611'
# error = profile = '\greece-el-duh\'
# inner_id = '212939509'
# error = profile = '난 련주 ੯‧̀͡u\'
# inner_id = '6502320077'
# error = profile = '\shə • rēs\'
# inner_id = '1309983'
# error = profile = '출구없는 #먹통이네 ੯‧̀͡u\'
# inner_id = '32454758111'
# error = profile = '담이 ੯‧̀͡u\'
# inner_id = '8562060913'
# error = profile = '/ᐠ｡ꞈ｡ᐟ\ Miaujestad /ᐠ｡ꞈ｡ᐟ\'
# inner_id = '10743211174'
# error = profile = 'Star_Moon /ᐠ｡‸｡ᐟ\'
# inner_id = '39226791604'
# error = profile = ':\'
# inner_id = '2226786518'
# error = profile = '김달콩੯‧̀͡u\'
# inner_id = '12823937684'
# error = profile = '쿠키 ੯∙̀͡u\'
# inner_id = '40617537266'
# error = profile = 'sᴜ ᴊᴜɴɢ ੯‧̀͡u\'
# inner_id = '1564473489'
