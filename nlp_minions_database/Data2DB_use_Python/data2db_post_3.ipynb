# %%
# Python2DB class
import pymysql


class Python2DB():
    def __init__(self):
        self.WL_DB = pymysql.connect(host='220.90.200.176',
                                     port=3306,
                                     user='multi',
                                     passwd='multi!)@(',
                                     db = 'SocialAnalysis',
                                     charset='utf8')
        self.cursor = self.WL_DB.cursor()
        
    def select(self, table, column):
        sql_qr = """
            SELECT {0} FROM {1}
        """.format(column, table)
        self.cursor.execute(sql_qr)
        return self.cursor.fetchall()

    def insert(self, table, columns, values):
        sql_qr2 = """
            INSERT INTO {0}({1})
            VALUES ({2})
        """.format(table, columns, values)
        self.cursor.execute(sql_qr2)
        self.WL_DB.commit()

    def update(self, table, set_content, where_content):
        sql_qr3 = """
            UPDATE {0}
            SET {1}
            WHERE {2}
        """.format(table, set_content, where_content)
        self.cursor.execute(sql_qr3)
        self.WL_DB.commit()

    def delete(self, table, where_content):
        sql_qr4 = """
            DELETE FROM {0} WHERE {1}
        """.format(table, where_content)
        self.cursor.execute(sql_qr4)
        self.WL_DB.commit()

# %%
# 폴더 내 파일을 모두 불러옴(생략가능)
import glob

post_path = "C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\*"
post_file_list = glob.glob(post_path)
post_file_list
# Out:
# ['C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\FOLLOW_RELATION.json',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\INSTA_FOLLOW_POST.txt',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\INSTA_POST_FINAL.txt',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\INSTA_USERS.txt']

# %%
# 파일을 데이터프레임으로 불러옴
import pandas as pd

post_data = pd.read_csv(post_file_list[2])
post_data
# Out:
#          Unnamed: 0            post_date    insta_id  \
# 0                 0  2020-08-21 12:42:59  3079813342
# 1                 1  2020-08-20 13:04:05  3079813342
# 2                 2  2020-08-19 21:10:30  3079813342
# 3                 3  2020-08-19 13:20:51  3079813342
# 4                 4  2020-08-18 21:11:08  3079813342
# ...             ...                  ...         ...
# 6524629     6524629  2020-03-09 16:21:36  1485471357
# 6524630     6524630  2020-03-08 19:29:52  1485471357
# 6524631     6524631  2020-03-08 19:03:47  1485471357
# 6524632     6524632  2020-03-08 15:56:52  1485471357
# 6524633     6524633  2020-03-07 15:08:52  1485471357
#
#                                                    content      post_id
# 0        일주일 쉬었다고..\n힘들다..\n다시 열심히 시작~😎\n.\n.\n.\n#필라테스...  CEIv1mqFs36
# 1        낭만포차..이런 분위기 너무\n오랜만..🤭\n단연 최고는 남편이 볶아준 갓볶음밥👍👍...  CEGNdUhlWlj
# 2        콩트부녀~🧡💚💛💜\n찰떡콤비😎\n.\n.\n.\n#울산 #여행휴유증 #슈가브리움 #...  CEEgVA8FicP
# 3        여수의 발리❤\n안녕~~~~\n.\n.\n.\n#울산 #여수 #슈가브리움 #풀빌라\...  CEDqlMFlmx_
# 4        2020년 8월계획은..\n발리 한달살기였는데..\n코로나 땜에..모든게 물거품😭\...  CEB7m1_HGuG
# ...                                                    ...          ...
# 6524629  .\n.\n어제 아침부터 밤까지\n엄청 놀았더니\n오늘 진짜 피곤ㅋㅋㅋ\n.\n그래...  B9gRsYYFQC-
# 6524630  .\n.\n은행나무 오랫만~✋\n일년에 한두번은 오던 곳인데\n올만에 온 듯😉\n....  B9eCcdOFGg7
# 6524631  .\n.\n용문산 계곡물은\n여전히 맑고 \n용문산 공기는 여전히 좋네^^\n.\n...  B9d_ddPFAH6
# 6524632  .\n.\n오늘도 웨이팅 장난 아닌 곳^^\n.\n양도 많고 울 아들들 겨자맛\n ...  B9dqEXwFciL
# 6524633  .\n.\n약국에서 30분정도 줄 서서\n마스크2장 간신히 구입😰\n.\n지나가다 ...  B9a_x9GFEeV
#
# [6524634 rows x 5 columns]

# %%
# team_idx 삽입/수정
post_data['team_idx'] = '3'
post_data
# Out:
#          Unnamed: 0            post_date    insta_id  \
# 0                 0  2020-08-21 12:42:59  3079813342
# 1                 1  2020-08-20 13:04:05  3079813342
# 2                 2  2020-08-19 21:10:30  3079813342
# 3                 3  2020-08-19 13:20:51  3079813342
# 4                 4  2020-08-18 21:11:08  3079813342
# ...             ...                  ...         ...
# 6524629     6524629  2020-03-09 16:21:36  1485471357
# 6524630     6524630  2020-03-08 19:29:52  1485471357
# 6524631     6524631  2020-03-08 19:03:47  1485471357
# 6524632     6524632  2020-03-08 15:56:52  1485471357
# 6524633     6524633  2020-03-07 15:08:52  1485471357
#
#                                                    content      post_id  \
# 0        일주일 쉬었다고..\n힘들다..\n다시 열심히 시작~😎\n.\n.\n.\n#필라테스...  CEIv1mqFs36
# 1        낭만포차..이런 분위기 너무\n오랜만..🤭\n단연 최고는 남편이 볶아준 갓볶음밥👍👍...  CEGNdUhlWlj
# 2        콩트부녀~🧡💚💛💜\n찰떡콤비😎\n.\n.\n.\n#울산 #여행휴유증 #슈가브리움 #...  CEEgVA8FicP
# 3        여수의 발리❤\n안녕~~~~\n.\n.\n.\n#울산 #여수 #슈가브리움 #풀빌라\...  CEDqlMFlmx_
# 4        2020년 8월계획은..\n발리 한달살기였는데..\n코로나 땜에..모든게 물거품😭\...  CEB7m1_HGuG
# ...                                                    ...          ...
# 6524629  .\n.\n어제 아침부터 밤까지\n엄청 놀았더니\n오늘 진짜 피곤ㅋㅋㅋ\n.\n그래...  B9gRsYYFQC-
# 6524630  .\n.\n은행나무 오랫만~✋\n일년에 한두번은 오던 곳인데\n올만에 온 듯😉\n....  B9eCcdOFGg7
# 6524631  .\n.\n용문산 계곡물은\n여전히 맑고 \n용문산 공기는 여전히 좋네^^\n.\n...  B9d_ddPFAH6
# 6524632  .\n.\n오늘도 웨이팅 장난 아닌 곳^^\n.\n양도 많고 울 아들들 겨자맛\n ...  B9dqEXwFciL
# 6524633  .\n.\n약국에서 30분정도 줄 서서\n마스크2장 간신히 구입😰\n.\n지나가다 ...  B9a_x9GFEeV
#
#         team_idx
# 0              3
# 1              3
# 2              3
# 3              3
# 4              3
# ...          ...
# 6524629        3
# 6524630        3
# 6524631        3
# 6524632        3
# 6524633        3
#
# [6524634 rows x 6 columns]

# %%
import re

db_class = Python2DB()  # 클래스 객체 선언
post_data_list = []  # 데이터 확인을 위한 리스트 선언
EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)  # 이모티콘 제거를 위한 EMOJI 변수

for i in range(len(post_data)):  # 데이터프레임의 크기만큼 돌게 설정
    
    # 각 데이터 전처리
    if(str(post_data['content'][i]) != 'nan'):  # 이모티콘 제거 및 전처리 후 1000자까지만 저장
        content = EMOJI.sub(r'', post_data['content'][i]).replace(',', '  ').replace('"', '').replace("'", "")[:1000]
    else:
        content = ''

    post_data_list.append(
        {"inner_id": str(post_data['insta_id'][i]),
         "post_date": post_data['post_date'][i],
         "shortcode" : post_data['post_id'][i],
         "content" : content,
         "team_idx" : post_data['team_idx'][i]
        })

    try:
        db_class.insert('POST_3', 'shortcode, inner_id, post_date, content, team_idx','"{}", "{}", "{}", "{}", {}'.format(
            post_data['post_id'][i], str(post_data['insta_id'][i]), post_data['post_date'][i], content, post_data['team_idx'][i]))
    except:
        print("error = " + '"{}", "{}", "{}", "{}", {}'.format(
            post_data['post_id'][i], str(post_data['insta_id'][i]), post_data['post_date'][i], content, post_data['team_idx'][i]))
        pass
