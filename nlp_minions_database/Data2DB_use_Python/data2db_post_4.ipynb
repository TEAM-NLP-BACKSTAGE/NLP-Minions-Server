# %%
# Python2DB class
import pymysql


class Python2DB():
    def __init__(self):
        self.WL_DB = pymysql.connect(host='220.90.200.176',
                                     port=3306,
                                     user='multi',
                                     passwd='multi!)@(',
                                     db = 'SocialAnalysis',
                                     charset='utf8')
        self.cursor = self.WL_DB.cursor()
        
    def select(self, table, column):
        sql_qr = """
            SELECT {0} FROM {1}
        """.format(column, table)
        self.cursor.execute(sql_qr)
        return self.cursor.fetchall()

    def insert(self, table, columns, values):
        sql_qr2 = """
            INSERT INTO {0}({1})
            VALUES ({2})
        """.format(table, columns, values)
        self.cursor.execute(sql_qr2)
        self.WL_DB.commit()

    def update(self, table, set_content, where_content):
        sql_qr3 = """
            UPDATE {0}
            SET {1}
            WHERE {2}
        """.format(table, set_content, where_content)
        self.cursor.execute(sql_qr3)
        self.WL_DB.commit()

    def delete(self, table, where_content):
        sql_qr4 = """
            DELETE FROM {0} WHERE {1}
        """.format(table, where_content)
        self.cursor.execute(sql_qr4)
        self.WL_DB.commit()

# %%
# 폴더 내 파일을 모두 불러옴(생략가능)
import glob

post_path = "C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\*"
post_file_list = glob.glob(post_path)
post_file_list
# Out:
# ['C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\cc_post.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\gs_post.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\gw_post.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\jl_post.csv',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\4조\\Post\\sd_post.csv']

# %%
# 파일을 데이터프레임으로 불러옴
import pandas as pd

post_data = pd.read_csv(post_file_list[0])
post_data
# Out:
#           shortcode    insta_id    inner_id            post_date  \
# 0       CEasJz1JPgQ   jjjjy_o.o     1582899  2020-08-28 11:57:07
# 1       CEY3iR2pr-l   jjjjy_o.o     1582899  2020-08-27 18:58:06
# 2       CEYOgJUJ1KR   jjjjy_o.o     1582899  2020-08-27 12:59:32
# 3       CEWyKvgJE1C   jjjjy_o.o     1582899  2020-08-26 23:32:43
# 4       CEWde7hJDk1   jjjjy_o.o     1582899  2020-08-26 20:31:58
# ...             ...         ...         ...                  ...
# 110583  BA6ksSIO7Z7  baboheejin  2714923820  2016-01-24 17:32:49
# 110584  BA32YqrO7R0  baboheejin  2714923820  2016-01-23 16:09:42
# 110585  BA2V74-O7RG  baboheejin  2714923820  2016-01-23 02:06:55
# 110586  BA2M_NBO7d6  baboheejin  2714923820  2016-01-23 00:48:43
# 110587  BA2L55lu7bh  baboheejin  2714923820  2016-01-23 00:39:16
#
#                                              url  \
# 0       https://www.instagram.com/p/CEasJz1JPgQ/
# 1       https://www.instagram.com/p/CEY3iR2pr-l/
# 2       https://www.instagram.com/p/CEYOgJUJ1KR/
# 3       https://www.instagram.com/p/CEWyKvgJE1C/
# 4       https://www.instagram.com/p/CEWde7hJDk1/
# ...                                          ...
# 110583  https://www.instagram.com/p/BA6ksSIO7Z7/
# 110584  https://www.instagram.com/p/BA32YqrO7R0/
# 110585  https://www.instagram.com/p/BA2V74-O7RG/
# 110586  https://www.instagram.com/p/BA2M_NBO7d6/
# 110587  https://www.instagram.com/p/BA2L55lu7bh/
#
#                                           content  \
# 0                             냅킨은 이렇게 하는거죠 😏 ....
# 1       코스가 아니고 세트라며 음식이 한번에 나와서 당황했지만 맛있었음 .....
# 2                     더워서 해변은 못 다니고 바라보기만 😊 .....
# 3                                      굿나잇💫
# 4                         광안대교 야경보러 🌉
# ...                                           ...
# 110583
# 110584
# 110585                                        내가
# 110586                                        NaN
# 110587                                        NaN
#
#                                                 media_url  \
# 0       https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 1       https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 2       https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 3       https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 4       https://scontent-gmp1-1.cdninstagram.com/v/t51...
# ...                                                   ...
# 110583  https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 110584  https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 110585  https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 110586  https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 110587  https://scontent-gmp1-1.cdninstagram.com/v/t51...
#
#                                                   hashtag  \
# 0       #부산 #부산여행 #해운대 #시그니엘부산 #시그니엘라운지 #시그니엘 #라운지 #커피...
# 1                                           #시그니엘부산 #차오란
# 2                                                   #시그니엘
# 3                                      #반신욕 #족샷
# 4                                        #광안대교야경
# ...                                                   ...
# 110583  #겨울한파 에 채경이네 현관문이 #동파 되어 문이 안열려요 희지니 꼬모네집에 #피신...
# 110584  #토요일 #점심식사 는 #야니스시 에서 소울이 #공주님 이랑 놀아쪄영 아고고이뻐요 ...
# 110585  #인스타에가입한이유 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ김지노의 #국용표 사건ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 110586    #마카오맛집 #베네시안 #로드스토우베이커리 #에그타르트 줄서서 기다리기 스무개 주세요
# 110587                                 #마카오 #힐튼호텔 #콘래드마카오
#
#                                                region_tag  like_count  \
# 0                                                  부산 해운대          76
# 1                                                     차오란          69
# 2                                                  시그니엘부산          68
# 3                                                  시그니엘부산          50
# 4       부산 광안리해수욕장 - 廣安里海水浴場 GwangalliBeach, Busan, So...          78
# ...                                                   ...         ...
# 110583                                                NaN           5
# 110584                                   야니스시 'Yanisushi'           9
# 110585                                                NaN           1
# 110586                                         마카오 베네시안호텔           7
# 110587                           Conrad Macao Cotai Strip           7
#
#        view_count        crawling_time  team_idx
# 0             NaN  2020-08-31 03:32:07         4
# 1             NaN  2020-08-31 03:32:08         4
# 2             NaN  2020-08-31 03:32:08         4
# 3             NaN  2020-08-31 03:32:08         4
# 4             NaN  2020-08-31 03:32:08         4
# ...           ...                  ...       ...
# 110583        NaN  2020-09-06 07:24:51         4
# 110584        NaN  2020-09-06 07:24:52         4
# 110585        NaN  2020-09-06 07:24:52         4
# 110586        NaN  2020-09-06 07:24:52         4
# 110587        NaN  2020-09-06 07:24:52         4
#
# [110588 rows x 13 columns]

# %%
# team_idx 삽입/수정
post_data['team_idx'] = '4'

# %%
import re

db_class = Python2DB()  # 클래스 객체 선언
post_data_list = []  # 데이터 확인을 위한 리스트 선언
EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)  # 이모티콘 제거를 위한 EMOJI 변수

for i in range(len(post_data)):  # 데이터프레임의 크기만큼 돌게 설정
    
    # 각 데이터 전처리
    if(str(post_data['like_count'][i]) != 'nan'):
        like_count = int(post_data['like_count'][i])
    else:
        like_count = 0
        
    if(str(post_data['view_count'][i]) != 'nan'):  # 리스트로 저장된 여러 미디어의 view_count중 맨 앞 미디어의 view카운트를 저장(기준 view_count만 저장)
        try:
            view_count = int(re.findall('(?<=\[)[1-9]\w+', post_data['view_count'][i])[0])
        except:
            view_count = 0
    else:
        view_count = 0
        
    if(str(post_data['media_url'][i]) != 'nan'):
        media_url = post_data['media_url'][i].replace(',', '  ')
    else:
        media_url = ''
    
    if(str(post_data['content'][i]) != 'nan'):  # 이모티콘 제거 및 전처리 후 1000자까지만 저장
        content = EMOJI.sub(r'', post_data['content'][i]).replace(',', '  ').replace('"', '').replace("'", "")[:1000]
    else:
        content = ''
        
    if(str(post_data['region_tag'][i]) == 'nan'):
        post_data['region_tag'][i] = ''
        
    if(str(post_data['hashtag'][i]) != 'nan'): # 이모티콘 제거 및 전처리 후 1000자까지만 저장
        hashtag = EMOJI.sub(r'', post_data['hashtag'][i].replace(' #', '  ')[1:]).replace(',', '  ').replace('"', '').replace("'", "")[:1000]
    else:
        hashtag = ''
        
    post_data_list.append(
        {"inner_id": str(post_data['inner_id'][i]),
         "post_date": post_data['post_date'][i],
         "crawling_time": post_data['crawling_time'][i],
         "like_count": like_count,
         "view_count" : view_count,
         "url" : post_data['url'][i].replace(',', '  '),
         "shortcode" : post_data['shortcode'][i],
         "media_url" : media_url,
         "content" : content,
         "region_tag" : post_data['region_tag'][i],
         "hashtag" : hashtag,
         "team_idx" : post_data['team_idx'][i]
        })
    try:
        db_class.insert('POST_4', 'shortcode, inner_id, post_date, crawling_time, like_count, view_count, url, media_url,content, region_tag, hashtag, team_idx',
               '"{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", {}'.format(
                   post_data['shortcode'][i], str(post_data['inner_id'][i]), post_data['post_date'][i], post_data['crawling_time'][i], like_count, view_count, 
                   post_data['url'][i].replace(',', '  '), media_url,
                   content, post_data['region_tag'][i], hashtag, post_data['team_idx'][i]
               ))
    except:
        print("error = " + '"{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", {}'.format(
                   post_data['shortcode'][i], str(post_data['inner_id'][i]), post_data['post_date'][i], post_data['crawling_time'][i], like_count, view_count, 
                   post_data['url'][i].replace(',', '  '), media_url,
                   content, post_data['region_tag'][i], hashtag, post_data['team_idx'][i]))
        pass
# Out:
# c:\python\python36\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
