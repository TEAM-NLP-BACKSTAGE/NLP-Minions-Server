# %%
# 폴더 내 파일을 모두 불러옴(생략가능)
import glob

post_path = "C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\*"
post_file_list = glob.glob(post_path)
post_file_list
# Out:
# ['C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\FOLLOW_RELATION.json',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\INSTA_FOLLOW_POST.txt',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\INSTA_POST_FINAL.txt',
#  'C:\\Users\\ehhah\\Downloads\\멀캠\\플젝\\minions\\insta_data\\3조\\INSTA_USERS.txt']

# %%
# 파일을 데이터프레임으로 불러옴
import pandas as pd

post_data = pd.read_csv(post_file_list[2])
post_data
# Out:
#          shortcode              insta_id    inner_id            post_date  \
# 0      Bw--6JFFkE1                cyrano      114789  2019-05-03 11:45:47
# 1      BrZiJ9gFvdp                cyrano      114789  2018-12-15 16:05:40
# 2      BmaLQQbBxjP                cyrano      114789  2018-08-13 15:27:49
# 3      Blw0_aSBSWs                cyrano      114789  2018-07-28 14:04:25
# 4      BlruAQPhK-h                cyrano      114789  2018-07-26 14:27:10
# ...            ...                   ...         ...                  ...
# 87667  BGeiZIjAVYQ  sunny_____sunny_____  1489205084  2016-06-10 23:22:21
# 87668  BGcErMugVZf  sunny_____sunny_____  1489205084  2016-06-10 00:24:12
# 87669  BGcEKr7gVYC  sunny_____sunny_____  1489205084  2016-06-10 00:19:45
# 87670  BGcC1MHgVUQ  sunny_____sunny_____  1489205084  2016-06-10 00:08:05
# 87671  BGcCIQ9AVSQ  sunny_____sunny_____  1489205084  2016-06-10 00:01:57
#
#                                             url  \
# 0      https://www.instagram.com/p/Bw--6JFFkE1/
# 1      https://www.instagram.com/p/BrZiJ9gFvdp/
# 2      https://www.instagram.com/p/BmaLQQbBxjP/
# 3      https://www.instagram.com/p/Blw0_aSBSWs/
# 4      https://www.instagram.com/p/BlruAQPhK-h/
# ...                                         ...
# 87667  https://www.instagram.com/p/BGeiZIjAVYQ/
# 87668  https://www.instagram.com/p/BGcErMugVZf/
# 87669  https://www.instagram.com/p/BGcEKr7gVYC/
# 87670  https://www.instagram.com/p/BGcC1MHgVUQ/
# 87671  https://www.instagram.com/p/BGcCIQ9AVSQ/
#
#                                    content  \
# 0                                      NaN
# 1                                   위 디자인
# 2                     외근 나가는데 갑자기 소나기 오네.
# 3      인제 스피디움. 카트 타러 왔는데 서킷택시만 탔음. 재미있음.
# 4                                휴가의 첫식사.
# ...                                    ...
# 87667                                  NaN
# 87668                                  NaN
# 87669                                  NaN
# 87670                                  NaN
# 87671                                  NaN
#
#                                                media_url             hashtag  \
# 0      https://scontent-ssn1-1.cdninstagram.com/v/t51...                 NaN
# 1      https://scontent-ssn1-1.cdninstagram.com/v/t51...  #wedesign #위디자인페이퍼
# 2      https://scontent-ssn1-1.cdninstagram.com/v/t51...               #대략난감
# 3      https://scontent-ssn1-1.cdninstagram.com/v/t51...        #레이싱 #서킷 #카트
# 4      https://scontent-ssn1-1.cdninstagram.com/v/t51...            #춘천 #닭갈비
# ...                                                  ...                 ...
# 87667  https://scontent-nrt1-1.cdninstagram.com/v/t51...   #먹스타그램 #카레 #삼덕동맛집
# 87668  https://scontent-nrt1-1.cdninstagram.com/v/t51...      #카페 #브런치 #또띠아롤
# 87669  https://scontent-nrt1-1.cdninstagram.com/v/t51...    #카페 #브런치 #에그베네딕트
# 87670  https://scontent-nrt1-1.cdninstagram.com/v/t51...             #횡성 #카페
# 87671  https://scontent-nrt1-1.cdninstagram.com/v/t51...                 NaN
#
#         region_tag  like_count view_count        crawling_time  team_idx
# 0              NaN          22        NaN  2020-08-31 00:19:27         4
# 1              NaN          18        NaN  2020-08-31 00:19:27         4
# 2              NaN          20        NaN  2020-08-31 00:19:27         4
# 3          인제 스피디움          28        NaN  2020-08-31 00:19:27         4
# 4      통나무집 춘천닭갈비집          30        NaN  2020-08-31 00:19:27         4
# ...            ...         ...        ...                  ...       ...
# 87667        모나미카레          48        NaN  2020-09-05 12:42:06         4
# 87668    동성로 칸타로코코          58        NaN  2020-09-05 12:42:06         4
# 87669    The Brown          49        NaN  2020-09-05 12:42:06         4
# 87670          NaN          50        NaN  2020-09-05 12:42:09         4
# 87671          NaN          45        NaN  2020-09-05 12:42:09         4
#
# [87672 rows x 13 columns]

# %%
# team_idx 삽입/수정
post_data['team_idx'] = '4'

# %%
# Python2DB class
import pymysql


class Python2DB():
    def __init__(self):
        self.WL_DB = pymysql.connect(host='220.90.200.176',
                                     port=3306,
                                     user='multi',
                                     passwd='multi!)@(',
                                     db = 'SocialAnalysis',
                                     charset='utf8')
        self.cursor = self.WL_DB.cursor()
        
    def select(self, table, column):
        sql_qr = """
            SELECT {0} FROM {1}
        """.format(column, table)
        self.cursor.execute(sql_qr)
        return self.cursor.fetchall()

    def insert(self, table, columns, values):
        sql_qr2 = """
            INSERT INTO {0}({1})
            VALUES ({2})
        """.format(table, columns, values)
        self.cursor.execute(sql_qr2)
        self.WL_DB.commit()

    def update(self, table, set_content, where_content):
        sql_qr3 = """
            UPDATE {0}
            SET {1}
            WHERE {2}
        """.format(table, set_content, where_content)
        self.cursor.execute(sql_qr3)
        self.WL_DB.commit()

    def delete(self, table, where_content):
        sql_qr4 = """
            DELETE FROM {0} WHERE {1}
        """.format(table, where_content)
        self.cursor.execute(sql_qr4)
        self.WL_DB.commit()

# %%
import re

db_class = Python2DB()  # 클래스 객체 선언
post_data_list = []  # 데이터 확인을 위한 리스트 선언
EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)  # 이모티콘 제거를 위한 EMOJI 변수

for i in range(len(post_data)):  # 데이터프레임의 크기만큼 돌게 설정
    
    # 각 데이터 전처리
    if(str(post_data['like_count'][i]) != 'nan'):
        like_count = int(post_data['like_count'][i])
    else:
        like_count = 0
        
    if(str(post_data['view_count'][i]) != 'nan'):  # 리스트로 저장된 여러 미디어의 view_count중 맨 앞 미디어의 view카운트를 저장(기준 view_count만 저장)
        try:
            view_count = int(re.findall('(?<=\[)[1-9]\w+', post_data['view_count'][i])[0])
        except:
            view_count = 0
    else:
        view_count = 0
        
    if(str(post_data['media_url'][i]) != 'nan'):
        media_url = post_data['media_url'][i].replace(',', '  ')
    else:
        media_url = ''
    
    if(str(post_data['content'][i]) != 'nan'):  # 이모티콘 제거 및 전처리 후 1000자까지만 저장
        content = EMOJI.sub(r'', post_data['content'][i]).replace(',', '  ').replace('"', '').replace("'", "")[:1000]
    else:
        content = ''
        
    if(str(post_data['region_tag'][i]) == 'nan'):
        post_data['region_tag'][i] = ''
        
    if(str(post_data['hashtag'][i]) != 'nan'): # 이모티콘 제거 및 전처리 후 1000자까지만 저장
        hashtag = EMOJI.sub(r'', post_data['hashtag'][i].replace(' #', '  ')[1:]).replace(',', '  ').replace('"', '').replace("'", "")[:1000]
    else:
        hashtag = ''
        
    post_data_list.append(
        {"inner_id": str(post_data['inner_id'][i]),
         "post_date": post_data['post_date'][i],
         "crawling_time": post_data['crawling_time'][i],
         "like_count": like_count,
         "view_count" : view_count,
         "url" : post_data['url'][i].replace(',', '  '),
         "shortcode" : post_data['shortcode'][i],
         "media_url" : media_url,
         "content" : content,
         "region_tag" : post_data['region_tag'][i],
         "hashtag" : hashtag,
         "team_idx" : post_data['team_idx'][i]
        })
    try:
        db_class.insert('POST_4', 'shortcode, inner_id, post_date, crawling_time, like_count, view_count, url, media_url,content, region_tag, hashtag, team_idx',
               '"{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", {}'.format(
                   post_data['shortcode'][i], str(post_data['inner_id'][i]), post_data['post_date'][i], post_data['crawling_time'][i], like_count, view_count, 
                   post_data['url'][i].replace(',', '  '), media_url,
                   content, post_data['region_tag'][i], hashtag, post_data['team_idx'][i]
               ))
    except:
        print("error = " + '"{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", "{}", {}'.format(
                   post_data['shortcode'][i], str(post_data['inner_id'][i]), post_data['post_date'][i], post_data['crawling_time'][i], like_count, view_count, 
                   post_data['url'][i].replace(',', '  '), media_url,
                   content, post_data['region_tag'][i], hashtag, post_data['team_idx'][i]))
        pass
# Out:
# c:\python\python36\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# error = "B9I54kYnMJ8", "1442574897", "2020-02-29 14:31:01", "2020-09-04 12:14:37", "22", "0", "https://www.instagram.com/p/B9I54kYnMJ8/", "https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/88183159_111713067099679_6367394672786165896_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=107&_nc_ohc=-iI27STjnA0AX89xxkQ&_nc_tp=15&oh=c9c6d1737bfb1136065b02fb1d0c101c&oe=5F7A02DC  https://scontent-ssn1-1.cdninstagram.com/v/t51.2885
://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/67560309_124561508843494_6388056644319681958_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=110&_nc_ohc=XArPhIcgy6AAX_AlmOR&oh=7686186f527718254cd3ae0e1507deab&oe=5F7CEEF6  https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/67583460_1266307860213314_292187997647689488_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=102&_nc_ohc=2jwWwe_Ik8IAX_kghsk&oh=db660484f9a06e7da3562ce93413133c&oe=5F7CC65C  https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/69900308_1240624832783953_7336608237478014543_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=apKtec6NDzAAX-y6C8G&oh=7cc5b104a690bf08691374b3b7b77bbf&oe=5F7BF05A  https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/67348146_876398529399272_6674554427814290561_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=108&_nc_ohc=CNeAiF920MIAX912nU5&oh=521accf61b48ebe4795a3fc909cb1273&oe=5F7CC74D  https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/67517385_953892301626122_6603544328072588345_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=102&_nc_ohc=c-VDV3lDz6IAX_-ouRu&oh=ecd6afc22904a6304540025bc46be37f&oe=5F7CFE4A", "⠀⠀전부터 가고 싶었던 오후 2시쯤 갔더니 대기없이 바로 입장^^⠀대표메뉴일거라고 생각한 소바집이니 당연히 소바면이 훌륭하겠지하고 잔뜩 기대하고 갔는데   기대 이상!^^매일 아침 반죽하여 주문 즉시 제면~다른 소바들(돈카츠도 너무 촉촉   바삭.. 개인적으로는 지난번에 방문했던 돈까스전문점인 돈까스살롱보다도 더 입맛에 맞더라^^;또 언제가지.. 빨리 가고 싶다~~⠀⠀⠀⠀", "주간소바식당 "산"", "주간소바식당산 ", 4
# error = "BJlPS4MAcHx", "1064128807", "2016-08-27 03:24:20", "2020-09-06 00:24:08", "80", "0", "https://www.instagram.com/p/BJlPS4MAcHx/", "https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/14033061_622494634577423_446715248_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=111&_nc_ohc=cMajGqwWrfAAX-BqM_m&oh=8879e201a2319e624be2373e7a327bb8&oe=5F7DAEFB", "", "Canadian Exhibition Place Cne "The Ex"", "ferriswheel  photography  theex  cne  the6ix  fun  colourful  pretty  nofilter  friends  toronto  photography  hangout  photo  instadaily  daily  토론토  재밌다  데일리  행복  예쁘다  사진", 4
# error = "BaT-h9GlWUE", "2071568652", "2017-10-16 23:26:10", "2020-09-06 00:27:00", "30", "0", "https://www.instagram.com/p/BaT-h9GlWUE/", "", "2017.10.11 도쿄   시부야", ""Scramble Crossing" - Shibuya, Tokyo", "시부야  시부야스크램블  타임랩스  도쿄  일본  여행  shibuya  shibuyascramble  crossing  timelapse  tokyo  japan  travel", 4
# error = "BovEBdsHXFR", "617254133", "2018-10-10 11:11:28", "2020-09-05 20:24:20", "41", "0", "https://www.instagram.com/p/BovEBdsHXFR/", "https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/42724852_274554693175682_5774609249184939811_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=102&_nc_ohc=ulRfABK4pzYAX-LklFs&oh=a3bcd18c751ad7de4c05ce6ae5ba43de&oe=5F7BDA1C", "", "뮤지엄 "산"", "육지여행 후  제주 ", 4
